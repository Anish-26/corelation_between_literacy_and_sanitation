# %%
import pandas as pd

# %%
df5 = pd.read_csv("SDG6.csv")
df5
# Out:
#         Wealth and state/union territory  \
# 0                        Wealth quintile
# 1                                 Lowest
# 2                                 Second
# 3                                 Middle
# 4                                 Fourth
# 5                                Highest
# 6                  State/union territory
# 7                                  India
# 8                                  North
# 9                             Chandigarh
# 10                                 Delhi
# 11                               Haryana
# 12                      Himachal Pradesh
# 13                       Jammu & Kashmir
# 14                                Ladakh
# 15                                Punjab
# 16                             Rajasthan
# 17                           Uttarakhand
# 18                               Central
# 19                          Chhattisgarh
# 20                        Madhya Pradesh
# 21                         Uttar Pradesh
# ...

# %%
df5 = df5.drop(["Type of sanitation Improved sanitation facility¹"	,"Type of sanitation Shared facility²"	,"Type of sanitation Unimproved sanitation facility³"	,"Total","Percentage with limited sanitation service⁵"],axis = 1)
df5
# Out:
#         Wealth and state/union territory  \
# 0                        Wealth quintile
# 1                                 Lowest
# 2                                 Second
# 3                                 Middle
# 4                                 Fourth
# 5                                Highest
# 6                  State/union territory
# 7                                  India
# 8                                  North
# 9                             Chandigarh
# 10                                 Delhi
# 11                               Haryana
# 12                      Himachal Pradesh
# 13                       Jammu & Kashmir
# 14                                Ladakh
# 15                                Punjab
# 16                             Rajasthan
# 17                           Uttarakhand
# 18                               Central
# 19                          Chhattisgarh
# 20                        Madhya Pradesh
# 21                         Uttar Pradesh
# ...

# %%
df5 = df5.drop([0,1,2,3,4,5,6,7,8])
df5
# Out:
#         Wealth and state/union territory  \
# 9                             Chandigarh
# 10                                 Delhi
# 11                               Haryana
# 12                      Himachal Pradesh
# 13                       Jammu & Kashmir
# 14                                Ladakh
# 15                                Punjab
# 16                             Rajasthan
# 17                           Uttarakhand
# 18                               Central
# 19                          Chhattisgarh
# 20                        Madhya Pradesh
# 21                         Uttar Pradesh
# 22                                  East
# 23                                 Bihar
# 24                             Jharkhand
# 25                                Odisha
# 26                           West Bengal
# 27                             Northeast
# 28                     Arunachal Pradesh
# 29                                 Assam
# 30                               Manipur
# ...

# %%
df5 = df5.rename(columns={'Wealth and state/union territory': 'State/UT'})
df5 = df5.rename(columns={'Percentage with basic sanitation service⁴': 'Percentage with basic sanitation service'})
df5.head()
# Out:
#             State/UT  Percentage with basic sanitation service
# 9         Chandigarh                                      85.0
# 10             Delhi                                      81.1
# 11           Haryana                                      85.0
# 12  Himachal Pradesh                                      81.7
# 13   Jammu & Kashmir                                      75.7

# %%
df5.to_csv(r"C:\Users\Anish\OneDrive\Desktop\minor\DATA\san.csv", index=False)
